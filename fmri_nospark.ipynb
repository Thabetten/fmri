# %%
#import

import pandas as pd
import numpy as np
import matplotlib as ml
import scipy as sc
import sklearn as sk

# %%
#get data. note the size is limited as I did not have enough ram to load it all

mri_1 = pd.read_csv("/home/harry/temple_job/data/t1w.csv", nrows = 100000)


mri_1.head()
# Out:
# /home/harry/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (83,84,87,88,89,93,94,96,98,99,102,107,108,109,110,111,112,114,115,116,118,120,121,122,123,124,125,127) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0            _created.$date  \
# 0           0  2017-06-02T23:46:37.000Z
# 1           0  2017-06-04T04:48:30.000Z
# 2           0  2017-06-04T04:50:03.000Z
# 3           0  2017-06-04T04:51:35.000Z
# 4           0  2017-06-04T04:52:15.000Z
#
#                                       _etag                  _id.$oid  \
# 0  e977337639152e97d9d16f2125af5186f852bcae  5931f8dd5fe5450007fa5993
# 1  c08b2262355c1f24ffb77709fe6dca7be9ae8242  5933911e75537f0007f1e940
# 2  128a6874f0d1fe67d9ff07c098b5e444c7c20cd6  5933917b75537f0007f1e941
# 3  40e9c3be3b4f046c78180d3c31289c6d3e6e481b  593391d775537f0008bcd3bd
# 4  b3f60316a76c4fa86d04e3fd510fffaddab1ea94  593391ff75537f0007f1e942
#
#              _updated.$date bids_meta.modality  \
# 0  2017-06-02T23:46:37.000Z                T1w
# 1  2017-06-04T04:48:30.000Z                T1w
# 2  2017-06-04T04:50:03.000Z                T1w
# 3  2017-06-04T04:51:35.000Z                T1w
# 4  2017-06-04T04:52:15.000Z                T1w
#
#                                 bids_meta.subject_id       cjv       cnr  \
# 0  7d3295fffae7b7c2fd051352e4d54cca27c22ce7f75de3...  0.302542  4.148241
# 1  29db0c6782dbd5000559ef4d9e953e300e2b479eed26d8...  0.325249  3.953107
# 2  349c41201b62db851192665c504b350ff98c6b45fb62a8...  0.323290  3.868315
# 3  6208ef0f7750c111548cf90b6ea1d0d0a66f6bff40dbef...  0.290967  4.182846
# 4  7a61b53701befdae0eeeffaecc73f14e20b537bb0f8b91...  0.318241  4.049955
#
#         efc  ...  bids_meta.TotalReadoutTime  bids_meta.ConversionSoftware  \
# 0  0.694887  ...                         NaN                           NaN
# 1  0.535776  ...                         NaN                           NaN
# 2  0.589058  ...                         NaN                           NaN
# 3  0.603649  ...                         NaN                           NaN
# 4  0.576949  ...                         NaN                           NaN
#
#    bids_meta.ConversionSoftwareVersion  bids_meta.InstitutionName  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                        NaN
# 4                                  NaN                        NaN
#
#    bids_meta.InstitutionAddress  bids_meta.PartialFourier  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#    bids_meta.PulseSequenceDetails  bids_meta.ParallelReductionFactorInPlane  \
# 0                             NaN                                       NaN
# 1                             NaN                                       NaN
# 2                             NaN                                       NaN
# 3                             NaN                                       NaN
# 4                             NaN                                       NaN
#
#    bids_meta.TaskName  bids_meta.ParallelAcquisitionTechnique
# 0                 NaN                                     NaN
# 1                 NaN                                     NaN
# 2                 NaN                                     NaN
# 3                 NaN                                     NaN
# 4                 NaN                                     NaN
#
# [5 rows x 129 columns]

# %%
mri_1.describe()
# Out:
#        Unnamed: 0            cjv            cnr            efc          fber  \
# count    100000.0  100000.000000  100000.000000  100000.000000  1.000000e+05
# mean          0.0       0.384597       3.554010       0.556273  3.286726e+03
# std           0.0       0.147755       0.752343       0.089098  2.466163e+04
# min           0.0       0.217821       0.233361       0.392962  0.000000e+00
# 25%           0.0       0.310835       3.344282       0.496420  1.725912e+03
# 50%           0.0       0.341153       3.734944       0.529690  2.283744e+03
# 75%           0.0       0.397090       4.038929       0.579414  2.714450e+03
# max           0.0       4.700719       5.465214       0.973924  6.826809e+06
#
#             fwhm_avg         fwhm_x         fwhm_y         fwhm_z  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        3.553012       3.383245       3.799332       3.476459
# std         0.527446       0.522516       0.615209       0.631615
# min         1.051241       0.870163       1.063210       1.027750
# 25%         3.346315       3.169094       3.633910       3.199200
# 50%         3.467015       3.246346       3.769270       3.328950
# 75%         3.664188       3.431588       3.975195       3.527560
# max        17.871167      18.151300      15.961300      19.500900
#
#             icvs_csf  ...  bids_meta.NumberOfAverages  \
# count  100000.000000  ...                       672.0
# mean        0.201276  ...                         1.0
# std         0.020814  ...                         0.0
# min         0.076941  ...                         1.0
# 25%         0.189821  ...                         1.0
# 50%         0.198090  ...                         1.0
# 75%         0.213427  ...                         1.0
# max         0.511196  ...                         1.0
#
#        bids_meta.NumberOfPhaseEncodingSteps  \
# count                            672.000000
# mean                             254.928571
# std                                1.067451
# min                              239.000000
# 25%                              255.000000
# 50%                              255.000000
# 75%                              255.000000
# max                              255.000000
#
#        bids_meta.PercentPhaseFieldOfView  bids_meta.PercentSampling  \
# count                          672.00000                      672.0
# mean                            99.96875                      100.0
# std                              0.46701                        0.0
# min                             93.00000                      100.0
# 25%                            100.00000                      100.0
# 50%                            100.00000                      100.0
# 75%                            100.00000                      100.0
# max                            100.00000                      100.0
#
#        bids_meta.PixelBandwidth  bids_meta.TotalScanTimeSec  \
# count               1344.000000                  672.000000
# mean                 227.383185                  362.910714
# std                  158.766958                    1.334313
# min                  130.000000                  343.000000
# 25%                  199.000000                  363.000000
# 50%                  200.000000                  363.000000
# 75%                  200.000000                  363.000000
# max                  994.000000                  363.000000
#
#        bids_meta.EffectiveEchoSpacing  bids_meta.TotalReadoutTime  \
# count                    8.860000e+02                8.810000e+02
# mean                     6.480023e-06                6.500000e-06
# std                      3.803305e-07                1.339072e-19
# min                      0.000000e+00                6.500000e-06
# 25%                      6.500000e-06                6.500000e-06
# 50%                      6.500000e-06                6.500000e-06
# 75%                      6.500000e-06                6.500000e-06
# max                      7.400000e-06                6.500000e-06
#
#        bids_meta.ParallelReductionFactorInPlane  \
# count                                     582.0
# mean                                        2.0
# std                                         0.0
# min                                         2.0
# 25%                                         2.0
# 50%                                         2.0
# 75%                                         2.0
# max                                         2.0
#
#        bids_meta.ParallelAcquisitionTechnique
# count                                     0.0
# mean                                      NaN
# std                                       NaN
# min                                       NaN
# 25%                                       NaN
# 50%                                       NaN
# 75%                                       NaN
# max                                       NaN
#
# [8 rows x 89 columns]

# %%
#see how many unique values exist in identifying columns

etags = mri_1._etag.unique()
subject_ids = [mri_1['bids_meta.subject_id'].unique(), mri_1['bids_meta.subject_id'].value_counts()]
ids = mri_1['_id.$oid'].unique()

print(len(mri_1._etag.unique()), len(mri_1['bids_meta.subject_id'].unique()), len(ids))
#print(mri_1._etag.unique(), mri_1['bids_meta.subject_id'].unique())
# Out:
# 100000 8283 100000

# %%
#do this for all columns
for i in mri_1.columns:
    print(i, mri_1[i].nunique())
# Out:
# Unnamed: 0 1
# _created.$date 47964
# _etag 100000
# _id.$oid 100000
# _updated.$date 47964
# bids_meta.modality 1
# bids_meta.subject_id 8283
# cjv 15672
# cnr 18220
# efc 14873
# fber 15641
# fwhm_avg 18631
# fwhm_x 17867
# fwhm_y 17751
# fwhm_z 17958
# icvs_csf 15674
# icvs_gm 15674
# icvs_wm 15674
# inu_med 15647
# inu_range 15668
# provenance.md5sum 11258
# provenance.settings.testing 2
# provenance.software 1
# provenance.version 12
# qi_1 5321
# qi_2 18110
# rpve_csf 15673
# rpve_gm 15674
# rpve_wm 15674
# size_x 83
# size_y 118
# size_z 119
# snr_csf 15672
# snr_gm 15672
# snr_total 15673
# snr_wm 15672
# snrd_csf 18217
# snrd_gm 18217
# snrd_total 18218
# snrd_wm 18217
# spacing_x 715
# spacing_y 264
# spacing_z 606
# summary_bg_k 17826
# summary_bg_mad 18206
# summary_bg_mean 17818
# summary_bg_median 17641
# summary_bg_n 18179
# summary_bg_p05 11309
# summary_bg_p95 17826
# summary_bg_stdv 18213
# summary_csf_k 15672
# summary_csf_mad 15642
# summary_csf_mean 15655
# summary_csf_median 15660
# summary_csf_n 13321
# summary_csf_p05 15671
# summary_csf_p95 15671
# summary_csf_stdv 15661
# summary_gm_k 15672
# summary_gm_mad 15516
# summary_gm_mean 15639
# summary_gm_median 15640
# summary_gm_n 13462
# summary_gm_p05 15670
# summary_gm_p95 15672
# summary_gm_stdv 15657
# summary_wm_k 15672
# summary_wm_mad 15525
# summary_wm_mean 14953
# summary_wm_median 2441
# summary_wm_n 15162
# summary_wm_p05 15664
# summary_wm_p95 15652
# summary_wm_stdv 15662
# tpm_overlap_csf 18247
# tpm_overlap_gm 18216
# tpm_overlap_wm 18187
# wm2max 15672
# bids_meta.EchoTime 105
# bids_meta.FlipAngle 9
# bids_meta.MagneticFieldStrength 2
# bids_meta.Manufacturer 7
# bids_meta.ManufacturersModelName 22
# bids_meta.PhaseEncodingDirection 4
# bids_meta.RepetitionTime 287
# bids_meta.run_id 9
# bids_meta.session_id 68
# bids_meta.PulseSequenceType 5
# bids_meta.acq_id 11
# bids_meta.InversionTime 12
# bids_meta.AccelNumReferenceLines 1
# bids_meta.AccelerationFactorPE 1
# bids_meta.AcquisitionMatrix 2
# bids_meta.DeviceSerialNumber 30
# bids_meta.EchoTrainLength 3
# bids_meta.ImageType 9
# bids_meta.ImagingFrequency 251
# bids_meta.InPlanePhaseEncodingDirection 1
# bids_meta.MRAcquisitionType 1
# bids_meta.NumberOfAverages 1
# bids_meta.NumberOfPhaseEncodingSteps 2
# bids_meta.PatientPosition 2
# bids_meta.PercentPhaseFieldOfView 2
# bids_meta.PercentSampling 1
# bids_meta.PixelBandwidth 12
# bids_meta.ProtocolName 78
# bids_meta.ReceiveCoilName 10
# bids_meta.ScanOptions 4
# bids_meta.ScanningSequence 8
# bids_meta.SequenceName 11
# bids_meta.SequenceVariant 11
# bids_meta.SoftwareVersions 23
# bids_meta.TotalScanTimeSec 2
# bids_meta.TransmitCoilName 1
# bids_meta.VariableFlipAngleFlag 1
# provenance.email 2
# bids_meta.EffectiveEchoSpacing 3
# bids_meta.SliceEncodingDirection 1
# bids_meta.TotalReadoutTime 1
# bids_meta.ConversionSoftware 3
# bids_meta.ConversionSoftwareVersion 19
# bids_meta.InstitutionName 23
# bids_meta.InstitutionAddress 13
# bids_meta.PartialFourier 1
# bids_meta.PulseSequenceDetails 3
# bids_meta.ParallelReductionFactorInPlane 1
# bids_meta.TaskName 2
# bids_meta.ParallelAcquisitionTechnique 0

# %%
#drop na columns


mri_n = mri_1.dropna(axis = 1)

print(mri_n.shape)
for i in mri_n.columns:
    print(i, mri_n[i].nunique())
# Out:
# (100000, 78)
# Unnamed: 0 1
# _created.$date 47964
# _etag 100000
# _id.$oid 100000
# _updated.$date 47964
# bids_meta.modality 1
# bids_meta.subject_id 8283
# cjv 15672
# cnr 18220
# efc 14873
# fber 15641
# fwhm_avg 18631
# fwhm_x 17867
# fwhm_y 17751
# fwhm_z 17958
# icvs_csf 15674
# icvs_gm 15674
# icvs_wm 15674
# inu_med 15647
# inu_range 15668
# provenance.md5sum 11258
# provenance.settings.testing 2
# provenance.software 1
# provenance.version 12
# qi_2 18110
# rpve_csf 15673
# rpve_gm 15674
# rpve_wm 15674
# size_x 83
# size_y 118
# size_z 119
# snr_csf 15672
# snr_gm 15672
# snr_total 15673
# snr_wm 15672
# snrd_csf 18217
# snrd_gm 18217
# snrd_total 18218
# snrd_wm 18217
# spacing_x 715
# spacing_y 264
# spacing_z 606
# summary_bg_k 17826
# summary_bg_mad 18206
# summary_bg_mean 17818
# summary_bg_median 17641
# summary_bg_n 18179
# summary_bg_p05 11309
# summary_bg_p95 17826
# summary_bg_stdv 18213
# summary_csf_k 15672
# summary_csf_mad 15642
# summary_csf_mean 15655
# summary_csf_median 15660
# summary_csf_n 13321
# summary_csf_p05 15671
# summary_csf_p95 15671
# summary_csf_stdv 15661
# summary_gm_k 15672
# summary_gm_mad 15516
# summary_gm_mean 15639
# summary_gm_median 15640
# summary_gm_n 13462
# summary_gm_p05 15670
# summary_gm_p95 15672
# summary_gm_stdv 15657
# summary_wm_k 15672
# summary_wm_mad 15525
# summary_wm_mean 14953
# summary_wm_median 2441
# summary_wm_n 15162
# summary_wm_p05 15664
# summary_wm_p95 15652
# summary_wm_stdv 15662
# tpm_overlap_csf 18247
# tpm_overlap_gm 18216
# tpm_overlap_wm 18187
# wm2max 15672

# %%
#get types

type_name = list(zip(mri_n.columns, mri_n.dtypes))

# %%
#get numeric columns

useable = [i[0] for i in type_name if (i[1] == np.int64 or i[1] == np.float64)]
#useable = [i[0] for i in type_name]
print(useable)
# Out:
# ['Unnamed: 0', 'cjv', 'cnr', 'efc', 'fber', 'fwhm_avg', 'fwhm_x', 'fwhm_y', 'fwhm_z', 'icvs_csf', 'icvs_gm', 'icvs_wm', 'inu_med', 'inu_range', 'qi_2', 'rpve_csf', 'rpve_gm', 'rpve_wm', 'size_x', 'size_y', 'size_z', 'snr_csf', 'snr_gm', 'snr_total', 'snr_wm', 'snrd_csf', 'snrd_gm', 'snrd_total', 'snrd_wm', 'spacing_x', 'spacing_y', 'spacing_z', 'summary_bg_k', 'summary_bg_mad', 'summary_bg_mean', 'summary_bg_median', 'summary_bg_n', 'summary_bg_p05', 'summary_bg_p95', 'summary_bg_stdv', 'summary_csf_k', 'summary_csf_mad', 'summary_csf_mean', 'summary_csf_median', 'summary_csf_n', 'summary_csf_p05', 'summary_csf_p95', 'summary_csf_stdv', 'summary_gm_k', 'summary_gm_mad', 'summary_gm_mean', 'summary_gm_median', 'summary_gm_n', 'summary_gm_p05', 'summary_gm_p95', 'summary_gm_stdv', 'summary_wm_k', 'summary_wm_mad', 'summary_wm_mean', 'summary_wm_median', 'summary_wm_n', 'summary_wm_p05', 'summary_wm_p95', 'summary_wm_stdv', 'tpm_overlap_csf', 'tpm_overlap_gm', 'tpm_overlap_wm', 'wm2max']

# %%
#get intersection
#inter =  list(set(names) & set(useable))
#print(len(inter), inter)

# %%
#cols for new df

vals = ['_etag'] + useable

# %%
#make new df

mri_use = pd.read_csv("/home/harry/temple_job/data/t1w.csv", usecols = vals)
mri_use.drop(columns = 'Unnamed: 0', inplace = True)

# %%
mri_use.head()
# Out:
#                                       _etag       cjv       cnr       efc  \
# 0  e977337639152e97d9d16f2125af5186f852bcae  0.302542  4.148241  0.694887
# 1  c08b2262355c1f24ffb77709fe6dca7be9ae8242  0.325249  3.953107  0.535776
# 2  128a6874f0d1fe67d9ff07c098b5e444c7c20cd6  0.323290  3.868315  0.589058
# 3  40e9c3be3b4f046c78180d3c31289c6d3e6e481b  0.290967  4.182846  0.603649
# 4  b3f60316a76c4fa86d04e3fd510fffaddab1ea94  0.318241  4.049955  0.576949
#
#           fber  fwhm_avg    fwhm_x   fwhm_y   fwhm_z  icvs_csf  ...  \
# 0   141.180649  3.465414  3.425482  3.65108  3.31968  0.169771  ...
# 1  1967.281616  4.118737  4.117360  4.36596  3.87289  0.223549  ...
# 2  1211.442627  4.175967  4.105020  4.43056  3.99232  0.214853  ...
# 3  1234.891113  4.080417  4.000960  4.41971  3.82058  0.227958  ...
# 4  1456.063843  4.100280  4.020260  4.45114  3.82944  0.226260  ...
#
#    summary_wm_mean  summary_wm_median  summary_wm_n  summary_wm_p05  \
# 0       997.257263        1000.002930      162378.0      909.799707
# 1       998.950195         999.995361      201764.0      936.192764
# 2       999.302612        1000.002197      224692.0      936.545605
# 3       998.236267        1000.006042      223251.0      923.928131
# 4       995.513733        1000.019653      193940.0      898.169952
#
#    summary_wm_p95  summary_wm_stdv  tpm_overlap_csf  tpm_overlap_gm  \
# 0     1073.542987        50.020153         0.203462        0.527227
# 1     1057.988715        37.364407         0.226551        0.512594
# 2     1059.338263        37.493519         0.229701        0.510302
# 3     1065.950500        43.787952         0.223364        0.513645
# 4     1075.685144        53.522003         0.223068        0.509825
#
#    tpm_overlap_wm    wm2max
# 0        0.513727  0.573797
# 1        0.571660  0.688963
# 2        0.574516  0.647290
# 3        0.556552  0.667386
# 4        0.529621  0.701116
#
# [5 rows x 68 columns]

# %%
mri_use.shape
# Out:
# (1032817, 68)

# %%
#get useable section of new df, RAM still an issue

X = mri_use.iloc[0:1000000:10, 1:5]
X.dropna(inplace = True)

# %%
X.head()
# Out:
#          cjv       cnr       efc         fber
# 0   0.302542  4.148241  0.694887   141.180649
# 10  0.573794  2.358484  0.616924  1006.774475
# 20  0.388092  3.340486  0.495322  9595.016602
# 30  0.594722  2.280200  0.597560   121.311363
# 40  0.860001  1.651618  0.577664    36.284168

# %%
X.shape
# Out:
# (100000, 4)

# %%
from sklearn.cluster import DBSCAN

# %%
#get squares

avcol2 = [np.mean(X[i])**2 for i in X.columns]
print(avcol2)
# Out:
# [0.17836431143318907, 11.74795364500392, 0.28057795248530826, 9870974.734016705]

# %%
#euclideam distance between averages
dist = np.sqrt(np.sum(avcol2[:3]))
print(dist)
# Out:
# 3.49383684635136

# %%
#cluster
cluster = DBSCAN(eps=35, min_samples=100).fit(X.values)

# %%
#labels
cluster.labels_
# Out:
# array([ 0,  0, -1, ...,  0,  0,  0])

# %%
print(len(list(set(cluster.labels_))))
# Out:
# 15

# %%
test = mri_use.iloc[0:100000, 0:5]
test['label'] = cluster.labels_

# %%
test.head()
# Out:
#                                       _etag       cjv       cnr       efc  \
# 0  e977337639152e97d9d16f2125af5186f852bcae  0.302542  4.148241  0.694887
# 1  c08b2262355c1f24ffb77709fe6dca7be9ae8242  0.325249  3.953107  0.535776
# 2  128a6874f0d1fe67d9ff07c098b5e444c7c20cd6  0.323290  3.868315  0.589058
# 3  40e9c3be3b4f046c78180d3c31289c6d3e6e481b  0.290967  4.182846  0.603649
# 4  b3f60316a76c4fa86d04e3fd510fffaddab1ea94  0.318241  4.049955  0.576949
#
#           fber  label
# 0   141.180649      0
# 1  1967.281616      0
# 2  1211.442627     -1
# 3  1234.891113      0
# 4  1456.063843      0

# %%
#see how many don't fit in clusters.
r = test[test['label'] == -1]
r.shape
# Out:
# (1577, 6)
